# %% [markdown]
# # Machine Learning for Alzheimer's Imaging
# ## Final Capstone Project - FullStack Academy Spring 2025 ML Cohort
# ### AKA AI Being Used to _Treat_ Critical Thinking Problems in the Elderly, Instead of Just Causing Them in the Young
# ### Author Dan McKay - June 2025

# %% [markdown]
# ## Exploratory Sandbox File

# %%
# Code Goes Here
# Initial Imports

import pandas as pd
import numpy as np

# import parquet reader
import pyarrow as pa
import pyarrow.parquet as pq

# basic graphing libraries
import seaborn as sns
import matplotlib.pyplot as plt

# import image processing libraries
import skimage
from skimage import io, transform
from PIL import Image
import io
import random

from io import BytesIO
import os
from datetime import datetime
from zoneinfo import ZoneInfo
import tensorflow as tf

# %% [markdown]
# #### Seed Block

# %%
# There's no comment in my head at the moment that would be remotely appropriate.
SEED = 42  # For SFW meme value.

# Set seeds
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# %% [markdown]
# ### Google CoLab upload block
# * Add Parquet files here
# * Disabled in final product

# %%
# Advanced propietary data file injection is one of many unique features of Google CoLab
# Okay, now that I've adverised having to upload the same external files every damn session as a positive thing, would I make a good boomer?
# from google.colab import files
# uploaded = files.upload()

print("Clear cell") # You will see this line a lot. It's just to clear the output.
# Out:
# Clear cell

# %% [markdown]
# ## File Reading and Initial Extraction
# Gonna be real, when I was writing this part, PARQUET files just seemed like a form of hate with extra steps.

# %%
# Read the parquet file "Alzheimers_Train_Dataset.parquet"
df000 = pd.read_parquet("Alzheimers_Train_Dataset.parquet", engine='pyarrow')

# Print the shape of the DataFrame
print("Shape of the DataFrame:", df000.shape)
# Out:
# Shape of the DataFrame: (5120, 2)

# %% [markdown]
# ### Image Display Testing

# %%
# Exploratory function to decode and dispaly one image
def decode_image_from_dict(image_dict):
    image_bytes = image_dict["bytes"]
    return Image.open(BytesIO(image_bytes))


# Please display the first 5 images in a single row with their labels, as well as what number they are in the dataset.
def display_images_with_labels(df, num_images=5, img_size=(128, 128)):
    fig, axes = plt.subplots(1, num_images, figsize=(15, 5))

    for i in range(num_images):
        img = decode_image_from_dict(df.loc[i, 'image'])
        img = img.resize(img_size)  # Resize the image to 128x128
        label = df.loc[i, 'label']

        axes[i].imshow(img)
        axes[i].set_title(f"Label: {label}\nIndex: {i}")
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

# Now, make a function to make a linebreak every 5 images, so that we can see the first 50 images in a grid format.
# It became 15 in the final submission because I got tired of scrolling past it to get to the actual training part.

def display_images_grid(df, num_images=15, img_size=(128, 128), images_per_row=5):
    num_rows = (num_images + images_per_row - 1) // images_per_row  # Calculate number of rows needed
    fig, axes = plt.subplots(num_rows, images_per_row, figsize=(15, num_rows * 3))

    for i in range(num_images):
        img = decode_image_from_dict(df.loc[i, 'image'])
        img = img.resize(img_size)  # Resize the image to 128x128
        label = df.loc[i, 'label']

        ax = axes[i // images_per_row, i % images_per_row]
        ax.imshow(img)
        ax.set_title(f"Label: {label}\nIndex: {i}")
        ax.axis('off')

    # Hide any unused subplots
    for j in range(num_images, num_rows * images_per_row):
        axes[j // images_per_row, j % images_per_row].axis('off')

    plt.tight_layout()
    plt.show()

# Display the first 10 images in a grid format
display_images_grid(df000, num_images=15, img_size=(128, 128), images_per_row=5)

# %% [markdown]
# #### Label Counts + Dataset Copy
# Why no, I DON'T trust myself not to destroy everything up til this point

# %%
# Just using the label column, please return the totals of each value in the label column
label_counts = df000['label'].value_counts()
# Print the label counts
print("Label counts:")
print(label_counts)

# Now, make a copy of df000 and call it df001. This doubles as a new restart point.
df001 = df000.copy()
# Out:
# Label counts:
# label
# 2    2566
# 3    1781
# 0     724
# 1      49
# Name: count, dtype: int64

# %% [markdown]
# ### Attempted Label Organizing
# The keyword is "Attempted"

# %%
# Change the label column to a categorical type
df001['label'] = df001['label'].astype('category')
# Change the labels to the string values
df001['label'] = df001['label'].cat.rename_categories({
    0: 'Mild Demented',
    1: 'Moderate Demented',
    2: 'Non Demented',
    3: 'Very Mild Demented'
})

# %%
# Display the first 5 images with their labels
display_images_with_labels(df001, num_images=5, img_size=(128, 128))

# %% [markdown]
# #### Converting back to numeric
# Except pure numbers are still recognized as strings.
#
# _Olde Nerde Proverb: "Why do things in one step, when you can make it fifteen?"_

# %%
# Now, lets change them back to integers, however make them so that Non Demented is 0, Mild Demented is 1, Very Mild Demented is 2, and Moderate Demented is 3
df001['label'] = df001['label'].cat.rename_categories({
    'Non Demented': 0,
    'Very Mild Demented': 1,
    'Mild Demented': 2,
    'Moderate Demented': 3
})

# %% [markdown]
# ### Label Confirmation
# My OCD grows ever stronger.

# %%
# Now print all the values in the label column
print("Label column values after renaming:")
print(df001['label'].unique())
# Now print the label counts again
label_counts = df001['label'].value_counts()

# Now print the datatypes of each column.
print("Label counts after renaming:")
print(label_counts)
# Out:
# Label column values after renaming:
# [0, 2, 1, 3]
# Categories (4, int64): [2, 3, 0, 1]
# Label counts after renaming:
# label
# 0    2566
# 1    1781
# 2     724
# 3      49
# Name: count, dtype: int64

# %% [markdown]
# #### Forced Data Conversion to Integers
# I 💜💜💜 ```git push -u origin main --force```
#
# ^^^Also, even just joking about this triggers my coder friends like I just spit in their can of Red Bull

# %%
# Now forcibly convert the label column to an integer type

df001['label'] = df001['label'].astype(int)
# Print the datatypes of each column
print("Data types of each column:")
print(df001.dtypes)
# Out:
# Data types of each column:
# image    object
# label     int32
# dtype: object

# %% [markdown]
# ## Test Dataset Wrangling

# %%
# Reorganizing the testing dataset as well
# Read the parquet file "Alzheimers_Test_Dataset.parquet"
dftest000 = pd.read_parquet("Alzheimers_Test_Dataset.parquet", engine='pyarrow')

# %% [markdown]
# #### MOAR IMAGES TO DISPLAY
# Real Talk: I'm just trying to make sure nothing is broken during image extraction. _I do not trust myself._

# %%
# Displaying the first 10 images from the test dataset in grid format
print("Shape of the test DataFrame:", dftest000.shape)
print("\nAgain, this is from the TEST dataset:\n")
display_images_grid(dftest000, num_images=10, img_size=(128, 128), images_per_row=5)
# It's crazy how many of these look like weird luchador masks
# Out:
# Shape of the test DataFrame: (1280, 2)
#
# Again, this is from the TEST dataset:

# %% [markdown]
# #### Deja Vu Block

# %%
# Just using the label column, please return the totals of each value in the label column
label_counts = dftest000['label'].value_counts()
# Print the label counts
print("Label counts:")
print(label_counts)
# Now, make a copy of df000 and call it df001
dftest001 = dftest000.copy()
# Out:
# Label counts:
# label
# 2    634
# 3    459
# 0    172
# 1     15
# Name: count, dtype: int64

# %% [markdown]
# ### Image Labeling
# This is temporary.

# %%
# Change the label column to a categorical type
dftest001['label'] = dftest001['label'].astype('category')
# Change the labels to the string values
dftest001['label'] = dftest001['label'].cat.rename_categories({
    0: 'Mild Demented',
    1: 'Moderate Demented',
    2: 'Non Demented',
    3: 'Very Mild Demented'
})

# Display the first 5 images with their labels
display_images_with_labels(dftest001, num_images=5, img_size=(128, 128))

# %% [markdown]
# ### Image Un-labeling
# Told you :P

# %%
dftest001['label'] = dftest001['label'].cat.rename_categories({
    'Non Demented': 0,
    'Very Mild Demented': 1,
    'Mild Demented': 2,
    'Moderate Demented': 3
})

# %%
# Now print all the values in the label column
print("Label column values after renaming:")
print(dftest001['label'].unique())
# Now print the label counts again
label_counts = dftest001['label'].value_counts()
# Now print the datatypes of each column
print("Label counts after renaming:")
print(label_counts)
# Out:
# Label column values after renaming:
# [1, 2, 0, 3]
# Categories (4, int64): [2, 3, 0, 1]
# Label counts after renaming:
# label
# 0    634
# 1    459
# 2    172
# 3     15
# Name: count, dtype: int64

# %% [markdown]
# ### Forced Integer Conversion. Again.
# It's very important that everyone's brain has a proper number attached.
#
# For The Harvest.

# %%
# Force the 'label' column to be an integer type with a sledgehammer plz k thnx bye
dftest001['label'] = dftest001['label'].astype(int)
# Print the datatypes of each column
print("Data types of each column:")
print(dftest001.dtypes)
# Out:
# Data types of each column:
# image    object
# label     int32
# dtype: object

# %% [markdown]
# ## LOTS MOAR IMPROTS!!!!
# It's like making sausage: ya don't wanna know.

# %%
# Some image analysis imports
import tensorflow as tf
from tensorflow.keras import layers, Input, models, Model # type: ignore
from tensorflow.keras.models import Sequential, load_model  # type: ignore
from tensorflow.keras.layers import ( # type: ignore
     Dense, Flatten, Dropout, MaxPooling2D, GlobalAveragePooling2D, MaxPooling2D)
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping  # type: ignore
from tensorflow.keras.layers import ( # type: ignore
    GlobalMaxPooling2D, Concatenate,
    Dense, Dropout, BatchNormalization, Activation, Lambda,
    RandomFlip, RandomRotation, RandomZoom, GaussianNoise
) # type: ignore
from tensorflow.keras.losses import SparseCategoricalCrossentropy  # type: ignore
from tensorflow.keras.applications import DenseNet201 # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore
from tensorflow.keras.preprocessing import image # type: ignore
import tensorflow.keras.backend as K # type: ignore

# %%
# Non-TF additional add-ons
import cv2
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, classification_report

# %% [markdown]
# ### Dataframe Copy
# Personal Competence Checkpoint Complete!

# %%
# Now, make a copy of df001
df002 = df001.copy()

# Time Stamp. You may notice a lot of these going forward.
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Code block last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")
# Out:
# Code block last run at 05:35:46 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ### Initial Train Test Split

# %%
# Split the DataFrame into training and testing sets
train_df, test_df = train_test_split(df002, test_size=0.2, random_state=42, stratify=df001['label'])

# NumPy conversion

def decode_image_bytes(img_obj):
    image_bytes = img_obj['bytes']  # ✅ Extract the actual bytes
    image = Image.open(io.BytesIO(image_bytes)).convert("RGB")  # Ensure 3 channels
    image = image.resize((128, 128))
    return np.array(image) / 255.0  # Normalize to [0, 1]

# Apply decoding
images_np = np.stack(df001['image'].apply(decode_image_bytes))
labels_np = df001['label'].values

# Step 2: Split data
X_train, X_test, y_train, y_test = train_test_split(
    images_np, labels_np, test_size=0.2, random_state=42, stratify=labels_np
)

# Step 3: Convert to TensorFlow datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(4096).batch(32)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(32)

now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Train Test Split last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")
# Out:
# Train Test Split last run at 05:36:52 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# # The Actual Training Model

# %% [markdown]
# ### Custom Distortion Functions
# #### Custom Squish + Gaussian Blur
#
# Younger me would have probably used this part as a dream journal too.
#
# <sub>My paralysis demon told me to buy bitcoin again I don't deserve this ;__;</sub>

# %%
# Blur function
def random_blur(image, blur_chance=0.3, ksize=(3, 3), sigma=0.4):
    def _blur_fn(img):
        if np.random.rand() < blur_chance:
            img = img.numpy()
            blurred = cv2.GaussianBlur(img, ksize, sigmaX=sigma)
            return blurred.astype(np.float32)
        return img.numpy().astype(np.float32)

    blurred_img = tf.py_function(_blur_fn, [image], tf.float32)
    blurred_img.set_shape(image.shape)  # 👈 VERY important!
    return blurred_img

def random_squish(image):
    height = tf.shape(image)[0]
    width = tf.shape(image)[1]

    # Choose a random scale, preferably between 0.9 and 1.1.
    # I am not always the preferable type.
    width_scale = tf.random.uniform([], 0.975, 1.025)
    height_scale = tf.random.uniform([], 0.975, 1.025)

    new_height = tf.cast(tf.cast(height, tf.float32) * height_scale, tf.int32)
    new_width = tf.cast(tf.cast(width, tf.float32) * width_scale, tf.int32)

    squished = tf.image.resize(image, [new_height, new_width])
    return tf.image.resize(squished, [height, width])  # restore to original size

squish_layer = Lambda(random_squish)

# Time Stamp
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Squish function parameters updated at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰")
# Out:
# Squish function parameters updated at 05:36:55 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ## Data Augmentation Function
# Distortion Max Ultra!

# %%
# Compiled Data Augmentation for image randomization and small errors
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.08),
    tf.keras.layers.RandomZoom(0.08),
    tf.keras.layers.GaussianNoise(0.01),
    # Lambda(lambda x: random_blur(x, blur_chance=0.25, ksize=(3,3), sigma=0.4)),
    Lambda(random_squish), # custom squishing
], name="data_augmentation")

# Time Stamp
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Data Augmentation parameters updated at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰")
# Out:
# Data Augmentation parameters updated at 05:36:55 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ### Separated Utility Code for Compiler Injection - Yes that is a real description and not just mockery
# #### Class Weights, Callbacks, and Test/Train Split Batching & Shuffle

# %%
# Class Weights
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = dict(enumerate(np.clip(class_weights, 1.0, 22.0)))  # Clip weights to set range, even if it's a ridiculous one

# class_weights = dict(enumerate(class_weights)) # Uncapped version

# Callback Definitions

model_checkpoint = ModelCheckpoint(
    'best_densenet_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max'
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=4,
    min_lr=6e-8,
    mode='min'
)
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=9,
    restore_best_weights=True
)

# # Commented out when Oversample block is in effect, even if toggled to False
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(4096).batch(32)

test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(32)


# Time Stamp
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"DualPool Model utility parameters updated at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰")
# Out:
# DualPool Model utility parameters updated at 05:37:06 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# # DualPool DenseNet~~121~~ ~~169~~ ~~201?~~ ~~169??~~ no definitely 201 Model Compile
# ### GlobalAveragePooling + GlobalMaxPooling2D:
# ### Creating an unholy chimera that meddles with God's design
#
# Serial Build Compilation

# %%
# Creating the DenseNet201 base model with DualPool averaging

# Base model
base_model = DenseNet201(
    include_top=False,
    input_shape=(128, 128, 3),
    weights='imagenet')

base_model.trainable = True

# Input layer
inputs = Input(shape=(128, 128, 3))

# Randomly distorting pictures to reduce overfitting
x = data_augmentation(inputs)  # comment out if Oversample block is in effect, even if toggled to False

# Pass through base model
x = base_model(inputs, training=True)

# Freeze all but last whatever it says layers
for layer in base_model.layers[:-115]:
    layer.trainable = False

# Dual Pooling
avg_pool = GlobalAveragePooling2D()(x)
max_pool = GlobalMaxPooling2D()(x)
pooled = Concatenate()([avg_pool, max_pool])  # shape: (None, 2048)

# Serial style aggregation of layers

# Classifier head (deeper than before)
x = Dense(64, kernel_regularizer=l2(2e-4))(pooled) # L2 Regularization enabled
x = BatchNormalization()(x)                           # Pass the output of Dense to BatchNormalization
x = Activation('relu')(x)                             # Pass the output of BatchNormalization to Activation
x = Dropout(0.575)(x)                                  # Pass the output of Activation to Dropout


# Unused Extra Layers Below

# x = Dropout(0.6)(x)                                  # Aka a prayer to RNGesus for a lucky change near plateau, kept low to not otherwise interfere

# # For extra scrutiny. My model apparently benefits from eye glasses like most any other nerd.
# x = Dense(32, kernel_regularizer=l2(4e-5))(x)
# x = BatchNormalization()(x)
# x = Activation('relu')(x)
# x = Dropout(0.4)(x)

# # Experimental third Dense Layer that will probably backfire # Future me: yep
# x = Dense(32, kernel_regularizer=l2(4e-5))(x)
# x = BatchNormalization()(x)
# x = Activation('relu')(x)
# x = Dropout(0.25)(x)

# Output
outputs = Dense(4, activation='softmax')(x)

# Final model
dualpool_model = Model(inputs=inputs, outputs=outputs)

# Compilation
dualpool_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=7.5e-6), loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy'])

# Time stamps are really helpful for telling me I've overwritten something valuable and should punch myself.
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"DualPool Model defined and compiled at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")

# Optional Summary
# dualpool_model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Dan\miniconda3\envs\py-env-prime\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# DualPool Model defined and compiled at 05:37:32 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# # MANUAL HARD BREAK POINT

# %%
# Insertable Stopping Point for the Run All function
# raise SystemExit("🛑 Manual checkpoint: stopping execution here.") # Comment out when not in use
print("Clear cell")
# Out:
# Clear cell

# %% [markdown]
# ## DualPool Loading Block

# %%
# Time Stamp variable
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))

# Loading the DenseNet201 model if it exists
try:
    if os.path.exists('best_dualpool201_model.keras'):
        dualpool_model = load_model('best_dualpool201_model.keras')
        print(f"✅ DualPool model loaded successfully at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰")
    else:
        raise FileNotFoundError("Model file 'best_dualpool201_model.keras' not found, training from scratch.")
except FileNotFoundError as e:
    print(f"❌ {e}")
except Exception as e:
    print(f"⚠️ Failed to load DualPool model: {type(e).__name__} - {e}")
# print("Clear cell")
# Out:
# ✅ DualPool model loaded successfully at 05:37:32 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# # DualPool Training Block
#
# The best reason to play videogames since CoVID

# %%
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
# DualPool Training Block

print(f"Training starting at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")

# Here is the training part. The part that lets me play videogames while being productive.
densenet_history = dualpool_model.fit(
    train_ds, # Use the original train_ds with integer labels
    validation_data=test_ds, # Use the original test_ds with integer labels
    epochs=150, # Reduced epochs for quicker testing
    class_weight=class_weights,
    callbacks=[model_checkpoint, reduce_lr, early_stop]
)

# Early Stoppage printed note. The model hasn't crashed, it's just become afraid of brain damage.
epochs_ran = len(densenet_history.history['loss'])
if epochs_ran < 150:
    print(f"\nTraining stopped early after {epochs_ran} epochs due to EarlyStopping at {now_pacific.strftime('%I:%M:%S %p')} ⏰")
else:
    print(f"\nTraining completed all 150 epochs at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} ⏰")
# Out:
# Training starting at 07:00:29 AM on July 01, 2025 Pacific Time ⏰
#
# Epoch 1/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 104s 212ms/step - accuracy: 0.2193 - loss: 2.6284 - val_accuracy: 0.2773 - val_loss: 1.5083 - learning_rate: 7.5000e-06
# Epoch 2/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.2721 - loss: 2.2370 - val_accuracy: 0.3418 - val_loss: 1.3975 - learning_rate: 7.5000e-06
# Epoch 3/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.3018 - loss: 2.0414 - val_accuracy: 0.4033 - val_loss: 1.3311 - learning_rate: 7.5000e-06
# Epoch 4/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.3530 - loss: 1.9200 - val_accuracy: 0.4521 - val_loss: 1.2895 - learning_rate: 7.5000e-06
# Epoch 5/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.3642 - loss: 1.8023 - val_accuracy: 0.4756 - val_loss: 1.2495 - learning_rate: 7.5000e-06
# Epoch 6/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.3966 - loss: 1.7018 - val_accuracy: 0.5068 - val_loss: 1.1992 - learning_rate: 7.5000e-06
# Epoch 7/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.4464 - loss: 1.5333 - val_accuracy: 0.5273 - val_loss: 1.1695 - learning_rate: 7.5000e-06
# Epoch 8/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.4789 - loss: 1.4792 - val_accuracy: 0.5449 - val_loss: 1.1350 - learning_rate: 7.5000e-06
# Epoch 9/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.5016 - loss: 1.4129 - val_accuracy: 0.5615 - val_loss: 1.1043 - learning_rate: 7.5000e-06
# Epoch 10/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.5141 - loss: 1.3642 - val_accuracy: 0.5928 - val_loss: 1.0653 - learning_rate: 7.5000e-06
# Epoch 11/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.5224 - loss: 1.3173 - val_accuracy: 0.6064 - val_loss: 1.0380 - learning_rate: 7.5000e-06
# Epoch 12/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.5465 - loss: 1.2653 - val_accuracy: 0.6240 - val_loss: 1.0075 - learning_rate: 7.5000e-06
# Epoch 13/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.5625 - loss: 1.2059 - val_accuracy: 0.6387 - val_loss: 0.9782 - learning_rate: 7.5000e-06
# Epoch 14/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.5778 - loss: 1.1463 - val_accuracy: 0.6455 - val_loss: 0.9463 - learning_rate: 7.5000e-06
# Epoch 15/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.5978 - loss: 1.1296 - val_accuracy: 0.6660 - val_loss: 0.9191 - learning_rate: 7.5000e-06
# Epoch 16/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.6112 - loss: 1.0723 - val_accuracy: 0.6758 - val_loss: 0.9043 - learning_rate: 7.5000e-06
# Epoch 17/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.6309 - loss: 1.0285 - val_accuracy: 0.6953 - val_loss: 0.8700 - learning_rate: 7.5000e-06
# Epoch 18/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.6479 - loss: 1.0069 - val_accuracy: 0.7031 - val_loss: 0.8461 - learning_rate: 7.5000e-06
# Epoch 19/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.6779 - loss: 0.9218 - val_accuracy: 0.7129 - val_loss: 0.8209 - learning_rate: 7.5000e-06
# Epoch 20/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.6846 - loss: 0.8821 - val_accuracy: 0.7246 - val_loss: 0.7983 - learning_rate: 7.5000e-06
# Epoch 21/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.6921 - loss: 0.8795 - val_accuracy: 0.7441 - val_loss: 0.7693 - learning_rate: 7.5000e-06
# Epoch 22/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.6971 - loss: 0.8228 - val_accuracy: 0.7549 - val_loss: 0.7385 - learning_rate: 7.5000e-06
# Epoch 23/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.7246 - loss: 0.7754 - val_accuracy: 0.7695 - val_loss: 0.7196 - learning_rate: 7.5000e-06
# Epoch 24/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.7623 - loss: 0.7186 - val_accuracy: 0.7793 - val_loss: 0.7056 - learning_rate: 7.5000e-06
# Epoch 25/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.7615 - loss: 0.7369 - val_accuracy: 0.7920 - val_loss: 0.6752 - learning_rate: 7.5000e-06
# Epoch 26/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.7697 - loss: 0.6864 - val_accuracy: 0.7998 - val_loss: 0.6641 - learning_rate: 7.5000e-06
# Epoch 27/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7879 - loss: 0.6956 - val_accuracy: 0.7988 - val_loss: 0.6533 - learning_rate: 7.5000e-06
# Epoch 28/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.7898 - loss: 0.6427 - val_accuracy: 0.8145 - val_loss: 0.6147 - learning_rate: 7.5000e-06
# Epoch 29/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.8027 - loss: 0.6259 - val_accuracy: 0.8135 - val_loss: 0.6063 - learning_rate: 7.5000e-06
# Epoch 30/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.8227 - loss: 0.5950 - val_accuracy: 0.8223 - val_loss: 0.5912 - learning_rate: 7.5000e-06
# Epoch 31/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.8351 - loss: 0.5740 - val_accuracy: 0.8271 - val_loss: 0.5731 - learning_rate: 7.5000e-06
# Epoch 32/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.8371 - loss: 0.5540 - val_accuracy: 0.8379 - val_loss: 0.5565 - learning_rate: 7.5000e-06
# Epoch 33/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.8402 - loss: 0.5344 - val_accuracy: 0.8486 - val_loss: 0.5339 - learning_rate: 7.5000e-06
# Epoch 34/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.8510 - loss: 0.5168 - val_accuracy: 0.8525 - val_loss: 0.5263 - learning_rate: 7.5000e-06
# Epoch 35/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.8667 - loss: 0.4838 - val_accuracy: 0.8633 - val_loss: 0.5080 - learning_rate: 7.5000e-06
# Epoch 36/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.8769 - loss: 0.4566 - val_accuracy: 0.8594 - val_loss: 0.4955 - learning_rate: 7.5000e-06
# Epoch 37/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.8788 - loss: 0.4549 - val_accuracy: 0.8662 - val_loss: 0.4845 - learning_rate: 7.5000e-06
# Epoch 38/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.8852 - loss: 0.4325 - val_accuracy: 0.8750 - val_loss: 0.4677 - learning_rate: 7.5000e-06
# Epoch 39/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.8996 - loss: 0.4035 - val_accuracy: 0.8770 - val_loss: 0.4526 - learning_rate: 7.5000e-06
# Epoch 40/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.8980 - loss: 0.4027 - val_accuracy: 0.8799 - val_loss: 0.4346 - learning_rate: 7.5000e-06
# Epoch 41/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.9157 - loss: 0.3792 - val_accuracy: 0.8809 - val_loss: 0.4349 - learning_rate: 7.5000e-06
# Epoch 42/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9161 - loss: 0.3632 - val_accuracy: 0.8838 - val_loss: 0.4148 - learning_rate: 7.5000e-06
# Epoch 43/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.9212 - loss: 0.3517 - val_accuracy: 0.8896 - val_loss: 0.4143 - learning_rate: 7.5000e-06
# Epoch 44/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9403 - loss: 0.3387 - val_accuracy: 0.8857 - val_loss: 0.4076 - learning_rate: 7.5000e-06
# Epoch 45/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9281 - loss: 0.3381 - val_accuracy: 0.8848 - val_loss: 0.3950 - learning_rate: 7.5000e-06
# Epoch 46/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.9295 - loss: 0.3241 - val_accuracy: 0.8936 - val_loss: 0.3864 - learning_rate: 7.5000e-06
# Epoch 47/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9344 - loss: 0.3103 - val_accuracy: 0.9014 - val_loss: 0.3787 - learning_rate: 7.5000e-06
# Epoch 48/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9403 - loss: 0.3057 - val_accuracy: 0.9004 - val_loss: 0.3655 - learning_rate: 7.5000e-06
# Epoch 49/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9509 - loss: 0.2869 - val_accuracy: 0.8994 - val_loss: 0.3615 - learning_rate: 7.5000e-06
# Epoch 50/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9453 - loss: 0.2876 - val_accuracy: 0.9033 - val_loss: 0.3561 - learning_rate: 7.5000e-06
# Epoch 51/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.9549 - loss: 0.2786 - val_accuracy: 0.9062 - val_loss: 0.3459 - learning_rate: 7.5000e-06
# Epoch 52/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9546 - loss: 0.2599 - val_accuracy: 0.9092 - val_loss: 0.3349 - learning_rate: 7.5000e-06
# Epoch 53/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.9592 - loss: 0.2559 - val_accuracy: 0.9121 - val_loss: 0.3325 - learning_rate: 7.5000e-06
# Epoch 54/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9566 - loss: 0.2639 - val_accuracy: 0.9180 - val_loss: 0.3286 - learning_rate: 7.5000e-06
# Epoch 55/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9632 - loss: 0.2398 - val_accuracy: 0.9170 - val_loss: 0.3212 - learning_rate: 7.5000e-06
# Epoch 56/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9676 - loss: 0.2310 - val_accuracy: 0.9219 - val_loss: 0.3132 - learning_rate: 7.5000e-06
# Epoch 57/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9671 - loss: 0.2351 - val_accuracy: 0.9170 - val_loss: 0.3054 - learning_rate: 7.5000e-06
# Epoch 58/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9732 - loss: 0.2055 - val_accuracy: 0.9268 - val_loss: 0.3049 - learning_rate: 7.5000e-06
# Epoch 59/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9712 - loss: 0.2109 - val_accuracy: 0.9248 - val_loss: 0.3000 - learning_rate: 7.5000e-06
# Epoch 60/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9742 - loss: 0.1997 - val_accuracy: 0.9268 - val_loss: 0.2900 - learning_rate: 7.5000e-06
# Epoch 61/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9747 - loss: 0.2019 - val_accuracy: 0.9326 - val_loss: 0.2867 - learning_rate: 7.5000e-06
# Epoch 62/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9742 - loss: 0.1989 - val_accuracy: 0.9277 - val_loss: 0.2820 - learning_rate: 7.5000e-06
# Epoch 63/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9778 - loss: 0.1839 - val_accuracy: 0.9316 - val_loss: 0.2856 - learning_rate: 7.5000e-06
# Epoch 64/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.9788 - loss: 0.1876 - val_accuracy: 0.9336 - val_loss: 0.2764 - learning_rate: 7.5000e-06
# Epoch 65/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9839 - loss: 0.1774 - val_accuracy: 0.9346 - val_loss: 0.2682 - learning_rate: 7.5000e-06
# Epoch 66/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9779 - loss: 0.1849 - val_accuracy: 0.9346 - val_loss: 0.2635 - learning_rate: 7.5000e-06
# Epoch 67/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9850 - loss: 0.1652 - val_accuracy: 0.9404 - val_loss: 0.2575 - learning_rate: 7.5000e-06
# Epoch 68/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9842 - loss: 0.1664 - val_accuracy: 0.9355 - val_loss: 0.2575 - learning_rate: 7.5000e-06
# Epoch 69/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9840 - loss: 0.1684 - val_accuracy: 0.9365 - val_loss: 0.2616 - learning_rate: 7.5000e-06
# Epoch 70/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9833 - loss: 0.1620 - val_accuracy: 0.9375 - val_loss: 0.2519 - learning_rate: 7.5000e-06
# Epoch 71/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9867 - loss: 0.1593 - val_accuracy: 0.9434 - val_loss: 0.2436 - learning_rate: 7.5000e-06
# Epoch 72/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9862 - loss: 0.1569 - val_accuracy: 0.9404 - val_loss: 0.2459 - learning_rate: 7.5000e-06
# Epoch 73/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9923 - loss: 0.1504 - val_accuracy: 0.9365 - val_loss: 0.2511 - learning_rate: 7.5000e-06
# Epoch 74/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9907 - loss: 0.1598 - val_accuracy: 0.9443 - val_loss: 0.2380 - learning_rate: 7.5000e-06
# Epoch 75/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.9902 - loss: 0.1357 - val_accuracy: 0.9453 - val_loss: 0.2373 - learning_rate: 7.5000e-06
# Epoch 76/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9930 - loss: 0.1338 - val_accuracy: 0.9385 - val_loss: 0.2377 - learning_rate: 7.5000e-06
# Epoch 77/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9888 - loss: 0.1394 - val_accuracy: 0.9463 - val_loss: 0.2280 - learning_rate: 7.5000e-06
# Epoch 78/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9892 - loss: 0.1299 - val_accuracy: 0.9385 - val_loss: 0.2266 - learning_rate: 7.5000e-06
# Epoch 79/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9915 - loss: 0.1327 - val_accuracy: 0.9424 - val_loss: 0.2271 - learning_rate: 7.5000e-06
# Epoch 80/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9930 - loss: 0.1203 - val_accuracy: 0.9395 - val_loss: 0.2172 - learning_rate: 7.5000e-06
# Epoch 81/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9935 - loss: 0.1251 - val_accuracy: 0.9434 - val_loss: 0.2215 - learning_rate: 7.5000e-06
# Epoch 82/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9918 - loss: 0.1159 - val_accuracy: 0.9453 - val_loss: 0.2132 - learning_rate: 7.5000e-06
# Epoch 83/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9944 - loss: 0.1113 - val_accuracy: 0.9463 - val_loss: 0.2069 - learning_rate: 7.5000e-06
# Epoch 84/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.9916 - loss: 0.1138 - val_accuracy: 0.9521 - val_loss: 0.2101 - learning_rate: 7.5000e-06
# Epoch 85/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9931 - loss: 0.1201 - val_accuracy: 0.9434 - val_loss: 0.2090 - learning_rate: 7.5000e-06
# Epoch 86/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9927 - loss: 0.1114 - val_accuracy: 0.9541 - val_loss: 0.2032 - learning_rate: 7.5000e-06
# Epoch 87/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9913 - loss: 0.1144 - val_accuracy: 0.9434 - val_loss: 0.2072 - learning_rate: 7.5000e-06
# Epoch 88/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9960 - loss: 0.0987 - val_accuracy: 0.9502 - val_loss: 0.2050 - learning_rate: 7.5000e-06
# Epoch 89/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9950 - loss: 0.0997 - val_accuracy: 0.9502 - val_loss: 0.2007 - learning_rate: 7.5000e-06
# Epoch 90/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9966 - loss: 0.0963 - val_accuracy: 0.9502 - val_loss: 0.1973 - learning_rate: 7.5000e-06
# Epoch 91/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9971 - loss: 0.0975 - val_accuracy: 0.9512 - val_loss: 0.1982 - learning_rate: 7.5000e-06
# Epoch 92/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9968 - loss: 0.0968 - val_accuracy: 0.9531 - val_loss: 0.1945 - learning_rate: 7.5000e-06
# Epoch 93/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9936 - loss: 0.1136 - val_accuracy: 0.9521 - val_loss: 0.1881 - learning_rate: 7.5000e-06
# Epoch 94/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9962 - loss: 0.0940 - val_accuracy: 0.9531 - val_loss: 0.1897 - learning_rate: 7.5000e-06
# Epoch 95/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9957 - loss: 0.0943 - val_accuracy: 0.9531 - val_loss: 0.1859 - learning_rate: 7.5000e-06
# Epoch 96/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9967 - loss: 0.0864 - val_accuracy: 0.9521 - val_loss: 0.1896 - learning_rate: 7.5000e-06
# Epoch 97/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.9942 - loss: 0.0954 - val_accuracy: 0.9561 - val_loss: 0.1833 - learning_rate: 7.5000e-06
# Epoch 98/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9972 - loss: 0.0869 - val_accuracy: 0.9590 - val_loss: 0.1822 - learning_rate: 7.5000e-06
# Epoch 99/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9969 - loss: 0.0903 - val_accuracy: 0.9521 - val_loss: 0.1808 - learning_rate: 7.5000e-06
# Epoch 100/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9977 - loss: 0.0788 - val_accuracy: 0.9551 - val_loss: 0.1828 - learning_rate: 7.5000e-06
# Epoch 101/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9960 - loss: 0.0879 - val_accuracy: 0.9521 - val_loss: 0.1803 - learning_rate: 7.5000e-06
# Epoch 102/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9973 - loss: 0.0909 - val_accuracy: 0.9492 - val_loss: 0.1828 - learning_rate: 7.5000e-06
# Epoch 103/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9961 - loss: 0.0862 - val_accuracy: 0.9590 - val_loss: 0.1737 - learning_rate: 7.5000e-06
# Epoch 104/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9973 - loss: 0.0777 - val_accuracy: 0.9580 - val_loss: 0.1732 - learning_rate: 7.5000e-06
# Epoch 105/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9973 - loss: 0.0731 - val_accuracy: 0.9570 - val_loss: 0.1708 - learning_rate: 7.5000e-06
# Epoch 106/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9955 - loss: 0.0765 - val_accuracy: 0.9551 - val_loss: 0.1740 - learning_rate: 7.5000e-06
# Epoch 107/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9955 - loss: 0.0820 - val_accuracy: 0.9551 - val_loss: 0.1720 - learning_rate: 7.5000e-06
# Epoch 108/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9979 - loss: 0.0740 - val_accuracy: 0.9541 - val_loss: 0.1718 - learning_rate: 7.5000e-06
# Epoch 109/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9968 - loss: 0.0732 - val_accuracy: 0.9551 - val_loss: 0.1709 - learning_rate: 7.5000e-06
# Epoch 110/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9975 - loss: 0.0715 - val_accuracy: 0.9580 - val_loss: 0.1703 - learning_rate: 1.5000e-06
# Epoch 111/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9978 - loss: 0.0758 - val_accuracy: 0.9570 - val_loss: 0.1681 - learning_rate: 1.5000e-06
# Epoch 112/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9971 - loss: 0.0678 - val_accuracy: 0.9561 - val_loss: 0.1691 - learning_rate: 1.5000e-06
# Epoch 113/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9987 - loss: 0.0686 - val_accuracy: 0.9580 - val_loss: 0.1681 - learning_rate: 1.5000e-06
# Epoch 114/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9974 - loss: 0.0680 - val_accuracy: 0.9561 - val_loss: 0.1681 - learning_rate: 1.5000e-06
# Epoch 115/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9985 - loss: 0.0678 - val_accuracy: 0.9570 - val_loss: 0.1685 - learning_rate: 1.5000e-06
# Epoch 116/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9972 - loss: 0.0770 - val_accuracy: 0.9551 - val_loss: 0.1686 - learning_rate: 3.0000e-07
# Epoch 117/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9981 - loss: 0.0662 - val_accuracy: 0.9561 - val_loss: 0.1685 - learning_rate: 3.0000e-07
# Epoch 118/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9973 - loss: 0.0654 - val_accuracy: 0.9570 - val_loss: 0.1681 - learning_rate: 3.0000e-07
# Epoch 119/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9973 - loss: 0.0777 - val_accuracy: 0.9580 - val_loss: 0.1669 - learning_rate: 3.0000e-07
# Epoch 120/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9985 - loss: 0.0691 - val_accuracy: 0.9580 - val_loss: 0.1665 - learning_rate: 3.0000e-07
# Epoch 121/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9989 - loss: 0.0656 - val_accuracy: 0.9590 - val_loss: 0.1664 - learning_rate: 3.0000e-07
# Epoch 122/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9991 - loss: 0.0646 - val_accuracy: 0.9580 - val_loss: 0.1664 - learning_rate: 3.0000e-07
# Epoch 123/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9957 - loss: 0.0756 - val_accuracy: 0.9590 - val_loss: 0.1661 - learning_rate: 3.0000e-07
# Epoch 124/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.9980 - loss: 0.0677 - val_accuracy: 0.9600 - val_loss: 0.1666 - learning_rate: 3.0000e-07
# Epoch 125/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9975 - loss: 0.0769 - val_accuracy: 0.9600 - val_loss: 0.1665 - learning_rate: 3.0000e-07
# Epoch 126/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9990 - loss: 0.0703 - val_accuracy: 0.9600 - val_loss: 0.1663 - learning_rate: 3.0000e-07
# Epoch 127/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9990 - loss: 0.0610 - val_accuracy: 0.9600 - val_loss: 0.1657 - learning_rate: 3.0000e-07
# Epoch 128/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9991 - loss: 0.0646 - val_accuracy: 0.9590 - val_loss: 0.1661 - learning_rate: 3.0000e-07
# Epoch 129/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9998 - loss: 0.0675 - val_accuracy: 0.9590 - val_loss: 0.1663 - learning_rate: 3.0000e-07
# Epoch 130/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9984 - loss: 0.0637 - val_accuracy: 0.9600 - val_loss: 0.1654 - learning_rate: 3.0000e-07
# Epoch 131/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9986 - loss: 0.0630 - val_accuracy: 0.9590 - val_loss: 0.1652 - learning_rate: 3.0000e-07
# Epoch 132/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9986 - loss: 0.0642 - val_accuracy: 0.9590 - val_loss: 0.1654 - learning_rate: 3.0000e-07
# Epoch 133/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9965 - loss: 0.0682 - val_accuracy: 0.9600 - val_loss: 0.1653 - learning_rate: 3.0000e-07
# Epoch 134/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9971 - loss: 0.0692 - val_accuracy: 0.9600 - val_loss: 0.1654 - learning_rate: 3.0000e-07
# Epoch 135/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9995 - loss: 0.0642 - val_accuracy: 0.9600 - val_loss: 0.1650 - learning_rate: 3.0000e-07
# Epoch 136/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9978 - loss: 0.0664 - val_accuracy: 0.9600 - val_loss: 0.1652 - learning_rate: 3.0000e-07
# Epoch 137/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9973 - loss: 0.0703 - val_accuracy: 0.9600 - val_loss: 0.1653 - learning_rate: 3.0000e-07
# Epoch 138/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.9987 - loss: 0.0651 - val_accuracy: 0.9609 - val_loss: 0.1653 - learning_rate: 3.0000e-07
# Epoch 139/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9990 - loss: 0.0736 - val_accuracy: 0.9600 - val_loss: 0.1648 - learning_rate: 3.0000e-07
# Epoch 140/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9989 - loss: 0.0687 - val_accuracy: 0.9600 - val_loss: 0.1645 - learning_rate: 3.0000e-07
# Epoch 141/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9981 - loss: 0.0718 - val_accuracy: 0.9609 - val_loss: 0.1650 - learning_rate: 3.0000e-07
# Epoch 142/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9986 - loss: 0.0628 - val_accuracy: 0.9600 - val_loss: 0.1652 - learning_rate: 3.0000e-07
# Epoch 143/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9980 - loss: 0.0662 - val_accuracy: 0.9590 - val_loss: 0.1656 - learning_rate: 3.0000e-07
# Epoch 144/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9975 - loss: 0.0706 - val_accuracy: 0.9600 - val_loss: 0.1644 - learning_rate: 3.0000e-07
# Epoch 145/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9952 - loss: 0.0725 - val_accuracy: 0.9600 - val_loss: 0.1641 - learning_rate: 3.0000e-07
# Epoch 146/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9986 - loss: 0.0658 - val_accuracy: 0.9600 - val_loss: 0.1639 - learning_rate: 3.0000e-07
# Epoch 147/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9985 - loss: 0.0672 - val_accuracy: 0.9600 - val_loss: 0.1640 - learning_rate: 3.0000e-07
# Epoch 148/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9998 - loss: 0.0588 - val_accuracy: 0.9590 - val_loss: 0.1639 - learning_rate: 3.0000e-07
# Epoch 149/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9982 - loss: 0.0664 - val_accuracy: 0.9609 - val_loss: 0.1640 - learning_rate: 3.0000e-07
# Epoch 150/150
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9984 - loss: 0.0682 - val_accuracy: 0.9590 - val_loss: 0.1644 - learning_rate: 3.0000e-07
#
# Training completed all 150 epochs at 07:00:29 AM ⏰

# %% [markdown]
# ## DualPool Evaluation and Saving

# %%
# DualPool Evaluation

test_loss, test_accuracy = dualpool_model.evaluate(test_ds)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# Temporarily commented out Val Loss and Val Accuracy during final run through on my local machine, as it required compilation.
# I skipped the compilation step on the final run through since this code is technically for demonstration and downloading, and my laptop is a potato.
print(f"Validation Loss: {densenet_history.history['val_loss'][-1]:.4f}, Validation Accuracy: {densenet_history.history['val_accuracy'][-1]:.4f}")
print(f"Testing done at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - accuracy: 0.9568 - loss: 0.1561
# Test Loss: 0.1635, Test Accuracy: 0.9600
# Testing done at 05:37:32 PM on July 03, 2025 Pacific Time ⏰

# %%
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
# DualPool Saving

dualpool_model.save("best_dualpool201_model.keras")
print(f"💾 DualPool model saved as 'best_dualpool201_model.keras at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰")
# Out:
# 💾 DualPool model saved as 'best_dualpool201_model.keras at 05:45:52 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ### DualPool Offline Saving
# * Specific to Google CoLab
# * Disabled in final product

# %%
# # Download DualPool file
# from google.colab import files
# files.download('best_dualpool201_model.keras')

# # Time Stamp
# now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
# print(f"💾 DualPool model downloaded at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰")
print("Clear cell")
# Out:
# Clear cell

# %% [markdown]
# ## DualPool F1 Evaluation

# %%
#F1 Scores

# 1. Get predictions from model
y_pred_probs = dualpool_model.predict(test_ds)
y_pred = np.argmax(y_pred_probs, axis=1)

# 2. Get true labels from test_ds
y_true = np.concatenate([y for x, y in test_ds], axis=0)

# 3. Compute F1 scores
f1_macro = f1_score(y_true, y_pred, average='macro')
f1_weighted = f1_score(y_true, y_pred, average='weighted')

# 4. Confirm order... this was purely debugging, leaving it in in case that bug reappears.
new_order = [0, 1, 2, 3]
y_pred = np.array([new_order[i] for i in y_pred])
y_true = np.array([new_order[i] for i in y_true])

# 5. Print the F1 Scores
print(f"\n📊 F1 Macro Score: {f1_macro:.4f}")
print(f"📊 F1 Weighted Score: {f1_weighted:.4f}")

# 6. Full classification report
print("\n📋 Classification Report:")
print(classification_report(y_true, y_pred, target_names=[
    "Non-Demented", "Very Mild", "Mild", "Moderate"
    ]))
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Code block last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 176s 4s/step
#
# 📊 F1 Macro Score: 0.9596
# 📊 F1 Weighted Score: 0.9599
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
# Non-Demented       0.96      0.96      0.96       513
#    Very Mild       0.96      0.94      0.95       356
#         Mild       0.97      0.98      0.97       145
#     Moderate       0.91      1.00      0.95        10
#
#     accuracy                           0.96      1024
#    macro avg       0.95      0.97      0.96      1024
# weighted avg       0.96      0.96      0.96      1024
#
# Code block last run at 05:49:01 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ## Densenet DualPool Confusion Matrix

# %%
# 1. Recompute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Order confirmation
order = [0, 1, 2, 3] # Somehow, I have to make sure this doesn't get scrambled. Because my dementia detecting code has dementia >:|
cm_display = cm[np.ix_(order, order)]

# 3. Plot heatmap with names unchanged
plt.figure(figsize=(8, 8))
sns.heatmap(cm_display, annot=True, fmt='d', cmap='PuBu', cbar=False,
            xticklabels=["Non-Demented", "Very Mild", "Mild", "Moderate"],
            yticklabels=["Non-Demented", "Very Mild", "Mild", "Moderate"])
plt.xlabel("DenseNet Prediction", fontsize=16)
plt.ylabel("Reality", fontsize=16)
plt.title("Confusion Matrix - DenseNet DualPool Version", fontsize=18)
# plt.tight_layout()
plt.show()

now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Code block last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")
# Out:
# Code block last run at 05:49:02 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ### Additional Upload Block
# * Use to load images in Google CoLab
# * Disabled in final build

# %%
# # Sometimes I just don't wanna scroll all the way to the top >_>
# from google.colab import files
# uploaded = files.upload()
print("Clear cell")
# Out:
# Clear cell

# %% [markdown]
# # Image Prediction Function
# #### This is the one that matters
# Instructions for now:
# * Place up to ten images with the same name in the same directory, and name them as a two-digit numbered jpg preceded by "test", e.g. "test01.jpg" through "test20.jpg"
# * JPEGs are to match the file type that was in the original compressed Parquet files. I've tried this as PNG conversions, and JPEGs just work a lot better.
# * IF you happen to be in Google CoLab, alternately upload it with the code block above.
# * Run the block below. It should give both a prediction and a Confidence rating.

# %%
# Define class names for output
class_names = ["Non-Demented", "Very Mild", "Mild", "Moderate"]

def predict_mri_batch(max_images=20):
    images = []
    predictions = []
    filenames = []
    found_any = False  # Flag to suppress file-not-found spam

    for i in range(1, max_images + 1):
        filename = f"test{str(i).zfill(2)}.jpg"
        if not os.path.exists(filename):
            continue  # Don't print anything yet
        found_any = True

        try:
            # Load image
            img_raw = tf.keras.utils.load_img(filename)
            width, height = img_raw.size

            if width < 128 or height < 128:
                print(f"❌ Skipping {filename}: image is too small ({width}x{height})")
                continue

            # Resize to 128x128
            img = img_raw.resize((128, 128))
            img_array = tf.keras.utils.img_to_array(img) / 255.0
            input_tensor = np.expand_dims(img_array, axis=0)

            # Predict
            pred = dualpool_model.predict(input_tensor, verbose=0)[0]
            top_idx = np.argmax(pred)
            top_conf = pred[top_idx]
            top_label = class_names[top_idx]

            # 2nd most likely class if top confidence is low
            title = f"{os.path.basename(filename)}\n{top_label}\n({top_conf:.1%})"
            if top_conf < 0.85:
                second_idx = np.argsort(pred)[-2]
                second_label = class_names[second_idx]
                second_conf = pred[second_idx]
                title += f"\n2nd Most Likely: {second_label} ({second_conf:.1%})"

            # Store for display
            images.append(img_array)
            predictions.append(title)
            filenames.append(filename)

        except Exception as e:
            print(f"❌ Error processing {filename}: {e}")

    if not found_any:
        print("❗ No matching images (test01.jpg–test20.jpg) were found in this folder.")
        return
    if not images:
        print("❗ All found images were invalid or skipped.")
        return

    # Display with matplotlib
    n = len(images)
    cols = 5
    rows = (n + cols - 1) // cols
    plt.figure(figsize=(cols * 3, rows * 4))
    for i in range(n):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(images[i])
        plt.title(predictions[i], fontsize=9)
        plt.axis('off')
    plt.suptitle("MRI Predictions")
    plt.tight_layout()
    plt.show()

# Timestamp for when it last ran
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Code block last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")
# Out:
# Code block last run at 05:49:02 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ## Image Prediction Run Block
# #### (Okay THIS is the one that matters, but you need to run the cell above first)

# %%
# Gonna keep this simple for now
predict_mri_batch() # type: ignore

now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Code block last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")
# Out:
# Code block last run at 05:49:35 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ## Image Reset Block
# This is just to dump the images currently uploaded specifically for predictions.

# %%
def clear_mri_predictions():
    global images, predictions, filenames
    images = []
    predictions = []
    filenames = []
    print("🧹 Cleared stored images and predictions from memory.")

    now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Code block last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")
# Out:
# Code block last run at 05:20:26 AM on July 03, 2025 Pacific Time ⏰

# %%
# Actual Function separated into a separate block
clear_mri_predictions()

now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Reset block last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")
# Out:
# 🧹 Cleared stored images and predictions from memory.
# Reset block last run at 05:20:40 AM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ### Google CoLab Image Deletion
# * Specific to Google CoLab
# * Disabled in the final version

# %%
# for i in range(1, 11):
#     file_path = f"test{str(i).zfill(2)}.jpg"
#     if os.path.exists(file_path):
#         os.remove(file_path)
#         print(f"🗑️ Deleted {file_path}")
#     else:
#         print(f"⚠️ Not found: {file_path}")

# %% [markdown]
# ## ~~Sanity Test~~ Direct Accuracy Sample Test
# Running the first X images in the testing set against the Prediction Function

# %%
def predict_test_batch(X_test, y_test, count=30, start=0): # default paremeters included
    predictions = []
    true_labels = []

    end = min(start + count, len(X_test))

    for i in range(start, end):
        image = np.expand_dims(X_test[i], axis=0)  # Add batch dimension
        pred = dualpool_model.predict(image, verbose=0)
        pred_class = np.argmax(pred[0])
        confidence = pred[0][pred_class]

        predictions.append((class_names[pred_class], confidence))
        true_labels.append(class_names[y_test[i]])

    # Combine into a clean table format
    for i, (pred, true) in enumerate(zip(predictions, true_labels), start=start + 1):
        label, conf = pred
        print(f"🧠 Image {i:02}: Predicted → {label:<14} ({conf:.1%}) | True → {true}")

    return predictions, true_labels

# Function execution with length and starting index
preds, truths = predict_test_batch(X_test, y_test, count=40, start=140) # put paraameters here

now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Function last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰")
# Out:
# 🧠 Image 141: Predicted → Mild           (100.0%) | True → Mild
# 🧠 Image 142: Predicted → Non-Demented   (97.6%) | True → Non-Demented
# 🧠 Image 143: Predicted → Non-Demented   (87.5%) | True → Non-Demented
# 🧠 Image 144: Predicted → Very Mild      (99.6%) | True → Very Mild
# 🧠 Image 145: Predicted → Non-Demented   (99.4%) | True → Non-Demented
# 🧠 Image 146: Predicted → Non-Demented   (53.4%) | True → Very Mild
# 🧠 Image 147: Predicted → Mild           (97.8%) | True → Mild
# 🧠 Image 148: Predicted → Non-Demented   (99.8%) | True → Non-Demented
# 🧠 Image 149: Predicted → Mild           (39.2%) | True → Non-Demented
# 🧠 Image 150: Predicted → Non-Demented   (66.9%) | True → Non-Demented
# 🧠 Image 151: Predicted → Very Mild      (93.3%) | True → Very Mild
# 🧠 Image 152: Predicted → Very Mild      (94.9%) | True → Very Mild
# 🧠 Image 153: Predicted → Non-Demented   (91.1%) | True → Non-Demented
# 🧠 Image 154: Predicted → Mild           (99.5%) | True → Mild
# 🧠 Image 155: Predicted → Non-Demented   (90.9%) | True → Very Mild
# 🧠 Image 156: Predicted → Mild           (92.4%) | True → Mild
# 🧠 Image 157: Predicted → Non-Demented   (96.4%) | True → Non-Demented
# 🧠 Image 158: Predicted → Non-Demented   (93.5%) | True → Non-Demented
# 🧠 Image 159: Predicted → Very Mild      (99.1%) | True → Very Mild
# 🧠 Image 160: Predicted → Non-Demented   (99.4%) | True → Non-Demented
# 🧠 Image 161: Predicted → Non-Demented   (97.7%) | True → Non-Demented
# 🧠 Image 162: Predicted → Non-Demented   (98.4%) | True → Non-Demented
# 🧠 Image 163: Predicted → Very Mild      (56.7%) | True → Very Mild
# 🧠 Image 164: Predicted → Non-Demented   (97.7%) | True → Non-Demented
# 🧠 Image 165: Predicted → Non-Demented   (97.8%) | True → Non-Demented
# 🧠 Image 166: Predicted → Non-Demented   (98.8%) | True → Non-Demented
# 🧠 Image 167: Predicted → Mild           (99.4%) | True → Mild
# 🧠 Image 168: Predicted → Very Mild      (89.2%) | True → Very Mild
# 🧠 Image 169: Predicted → Mild           (92.8%) | True → Mild
# 🧠 Image 170: Predicted → Non-Demented   (97.3%) | True → Non-Demented
# 🧠 Image 171: Predicted → Non-Demented   (84.7%) | True → Non-Demented
# 🧠 Image 172: Predicted → Non-Demented   (99.8%) | True → Non-Demented
# 🧠 Image 173: Predicted → Very Mild      (82.7%) | True → Very Mild
# 🧠 Image 174: Predicted → Mild           (47.6%) | True → Mild
# 🧠 Image 175: Predicted → Very Mild      (99.3%) | True → Very Mild
# 🧠 Image 176: Predicted → Non-Demented   (99.6%) | True → Non-Demented
# 🧠 Image 177: Predicted → Non-Demented   (97.4%) | True → Non-Demented
# 🧠 Image 178: Predicted → Non-Demented   (97.6%) | True → Non-Demented
# 🧠 Image 179: Predicted → Non-Demented   (99.3%) | True → Non-Demented
# 🧠 Image 180: Predicted → Very Mild      (94.2%) | True → Very Mild
# Function last run at 05:49:49 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ### Test Set Image Predictor for Validation
# * Select specific images from the testing set as entered by index number in the latter code block
# * Maximum of 5 at a time right now, but this can be easily changed.

# %%
# Specified Image Prediction Function from Testing Set
# Set maximum number of images specified directly below
def predict_testing_images(indices, X_data, y_data, class_names, max_images=10):
    try:
        if not isinstance(indices, (list, tuple)):
            raise ValueError("Please provide a list or tuple of indices.")
        if len(indices) > max_images:
            raise ValueError(f"You can only predict up to {max_images} images at once.")

        # Convert from 1-based to 0-based
        indices = [i - 1 for i in indices]

        n = len(indices)
        cols = 5
        rows = (n + cols - 1) // cols  # Calculate required rows

        plt.figure(figsize=(cols * 3, rows * 4))

        for i, index in enumerate(indices):
            adjusted_index = index + 1  # Displayed index (1-based)

            if index < 0 or index >= len(X_data):
                print(f"⚠️ Skipping invalid index: {adjusted_index} (out of bounds)")
                continue

            image = X_data[index]
            true_label = class_names[y_data[index]]

            input_tensor = np.expand_dims(image, axis=0)
            prediction = dualpool_model.predict(input_tensor, verbose=0)[0]

            top_idx = np.argmax(prediction)
            top_conf = prediction[top_idx]
            top_label = class_names[top_idx]

            # Second-best prediction
            second_idx = np.argsort(prediction)[-2]
            second_label = class_names[second_idx]
            second_conf = prediction[second_idx]

            # Title formatting
            title = (
                f"Image #{adjusted_index}\n"
                f"{top_label} ({top_conf:.1%})\n"
                f"True: {true_label}"
            )
            if top_conf < 0.85:
                title += f"\n2nd Most Likely: {second_label} ({second_conf:.1%})"

            plt.subplot(rows, cols, i + 1)
            plt.imshow(image)
            plt.axis('off')
            plt.title(title, fontsize=9)

        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"❌ Error: {e}")


# Timestamp
now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Function last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰")
# Out:
# Function last run at 05:49:49 PM on July 03, 2025 Pacific Time ⏰

# %%
# Code Execute
predict_testing_images([17,18,19,24,255], X_test, y_test, class_names)

now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
print(f"Code block last run at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰\n")
# Out:
# Code block last run at 05:49:52 PM on July 03, 2025 Pacific Time ⏰

# %% [markdown]
# ## Frivolous VS Code Styling Block
# I can make things so pretty!
#
# I can also brick a Jupyter notebook with this if inclined.... I really wish I hadn't learned about the second one...

# %%
# %%html
# <style>* {   color: aquamarine;
# # background-color: SpringGreen;
# # padding: 5px;
#
#  !important;}</style>
# Out:
# <style>* {   color: aquamarine;
# # background-color: SpringGreen;
# # padding: 5px;
#
#  !important;}</style>

# %% [markdown]
# # Oversample Function and Dataset Pre-definition Block
# #### And other ways to horribly sabotage your own code
# <sub> Note: I wanted to keep this albatross of a code block just to show I tried it, and it technically works </sub>
# <sub>if you move it to after initial Data Augmentation, but since it doesn't help accuracy at all, it has now </sub>
# <sub>been commented out and moved to the bottom to make the rest of the code more readable. </sub>

# %%
# # Toggle oversampling ON or OFF
# # All caps, because I really need to glance at this thing now and then for safety reasons

# ENABLE_OVERSAMPLING = False

# # Set class targets (based on your 8192 or 6656 total and GPU limits)


# desired_totals = {
#     0: 2048,  # non-demented (no change)
#     1: 1784,  # very mild dementia
#     2: 1088,  # mild dementia
#     3: 200   # moderate dementia
# }

# # desired_totals = {
# #     0: 2048,  # non-demented (yes, this is discarding some images)
# #     1: 2048,  # very mild dementia
# #     2: 2048,  # mild dementia
# #     3: 2048   # moderate dementia
# # }


# # Function to oversample or randomly undersample to a specific target
# def oversample_class_to_target(X, y, class_label, target_count):
#     class_indices = np.where(y == class_label)[0]
#     X_class = X[class_indices]
#     y_class = y[class_indices]

#     if target_count > len(X_class):
#         # Oversample
#         reps = int(np.ceil(target_count / len(X_class)))
#         X_aug = np.tile(X_class, (reps, 1, 1, 1))[:target_count]
#         y_aug = np.tile(y_class, reps)[:target_count]
#     else:
#         # Undersample randomly
#         idx = np.random.choice(len(X_class), target_count, replace=False)
#         X_aug = X_class[idx]
#         y_aug = y_class[idx]

#     ds = tf.data.Dataset.from_tensor_slices((X_aug, y_aug))
#     ds = ds.shuffle(2048).map(lambda x, y: (data_augmentation(x), y), num_parallel_calls=tf.data.AUTOTUNE)
#     return ds

# # Build dataset
# if ENABLE_OVERSAMPLING:
#     print("📈 Oversampling enabled with class targets:", desired_totals)
#     balanced_datasets = [
#         oversample_class_to_target(X_train, y_train, class_label, desired_totals[class_label])
#         for class_label in desired_totals
#     ]
#     train_ds = balanced_datasets[0]
#     for ds in balanced_datasets[1:]:
#         train_ds = train_ds.concatenate(ds)
#         # ds = ds.shuffle(2048).map(lambda x, y: (data_augmentation(x), y), num_parallel_calls=tf.data.AUTOTUNE)
#         ds = ds.shuffle(2048).map(lambda x, y: (data_augmentation(x), y))  # Removed AUTOTUNE

#     train_ds = train_ds.shuffle(4096).batch(32).prefetch(1)
# else:
#     print("📊 Using regular training dataset.")
#     train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
#     train_ds = train_ds.shuffle(4096).map(lambda x, y: (data_augmentation(x), y))
#     # train_ds = train_ds.batch(32).prefetch(tf.data.AUTOTUNE)
#     train_ds = train_ds.shuffle(6656).batch(32).prefetch(1)  # Removed AUTOTUNE



# # Time Stamp
# from datetime import datetime
# from zoneinfo import ZoneInfo
# now_pacific = datetime.now(ZoneInfo("America/Los_Angeles"))
# print(f"Oversample function updated at {now_pacific.strftime('%I:%M:%S %p on %B %d, %Y')} Pacific Time ⏰")
print ("Clear cell")
# Out:
# Clear cell
